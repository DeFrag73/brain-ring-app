# %%
# Додавання JavaScript коду для адміністративної панелі

# %%
## Як додати цей код до вашого проекту:

1. Додайте JavaScript код перед закриваючим тегом </body> у файлі admin.html
2. Цей код реалізує:
   - Функцію showSection для перемикання між секціями (питання, команди, гра, статистика)
   - Автоматичне завантаження останньої активної секції при оновленні сторінки
   - Візуальне виділення активного пункту меню

## Додаткові рекомендації:

1. Переконайтеся, що всі ваші секції мають правильні id, наприклад:
   - id="questions-section"
   - id="teams-section"
   - id="game-section"
   - id="stats-section"

2. Переконайтеся, що всі секції мають клас "content-section"

3. Якщо функція editQuestion також не визначена, додайте її реалізацію
   (якщо це потрібно для вашого застосунку)
